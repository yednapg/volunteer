# %% [markdown]
# <h1 style="text-align:center">Welcome @PyDelhi 🚀</h1>

# %% [markdown]
# # What is PyDelhi
# Non-Profit and Volunteer run Organisation. Community of technically inclined students, DEVELOPERS, professionals, teachers and entrepreneurs having a common primary interest in the <code>PYTHON</code>.
#
# # SSID = Python-Event
# # Password = Events@8899

# %% [markdown]
# # What we usually do? 😎
# We generally organise meetups, workshops or hackathons. Yes, we also organise PyCon India and PyDelhi Conf.

# %% [markdown]
# # How this MEETUP can help you?
# - Learn new stuff!
# - Hire or get hired!
# - Find collaborators for your project.
# - Free consulting/mentoring
# - Find like minded geeky friends :)

# %% [markdown]
# # How you can HELP?
# - Host a meetup / Organize a workshop in your institute
#  - Space
#  - Sponsorship
# - PyDelhi's reach with Social Media (Twitter / LinkedIn)
# - Conduct a Workshop / Give a Talk

# %% [markdown]
# <h1 style="text-align:center">Do you want to Volunteer?</h1>

# %% [markdown]
# <h1 style="text-align:center">Yes you can, Just let us know how you can help or join Volunteering Session at <code>1</code> PM</h1>

# %% [markdown]
# # Thank You, <code>Innovacer</code> for Sponsoring this Meetup
# <img src="https://storage.googleapis.com/infinity_bucket_static/staticfiles/image/site-logo/innovaccer-logo-black.svg">

# %% [markdown]
# # Thank You for coming, 🚀

# %% [markdown]
# # New & Old Volunteers please join discord for internal communication: https://bit.ly/pydelhi-chat
